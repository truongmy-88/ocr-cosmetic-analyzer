# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: flask in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: easyocr in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.7.2)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (4.10.0.84)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (10.4.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.2.6)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from flask->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: torch in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: torchvision>=0.5 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (0.19.0)
# Requirement already satisfied: opencv-python-headless in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (4.13.0.92)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (1.14.1)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: python-bidi in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (0.6.10)
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: Shapely in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: pyclipper in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: ninja in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from easyocr->-r requirements.txt (line 2)) (1.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from requests->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from requests->-r requirements.txt (line 5)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from requests->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from requests->-r requirements.txt (line 5)) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 7)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from torch->easyocr->-r requirements.txt (line 2)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from torch->easyocr->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from torch->easyocr->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from torch->easyocr->-r requirements.txt (line 2)) (3.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from torch->easyocr->-r requirements.txt (line 2)) (2024.6.1)
# Requirement already satisfied: imageio>=2.33 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from scikit-image->easyocr->-r requirements.txt (line 2)) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from scikit-image->easyocr->-r requirements.txt (line 2)) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from scikit-image->easyocr->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from scikit-image->easyocr->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/envs/env_pytorch/lib/python3.11/site-packages (from sympy->torch->easyocr->-r requirements.txt (line 2)) (1.3.0)

# %%
import subprocess, time, sys, os

os.chdir('/Users/phongla/Data/test2')   # path to your project

proc = subprocess.Popen(
    [sys.executable, 'app.py'],
    stdout=open('flask.log', 'w'),
    stderr=subprocess.STDOUT 
)   
time.sleep(3)
print(open('flask.log').read())
print("✅ Open http://localhost:5001")
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.19.238.14:5001
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 104-580-919
#
# ✅ Open http://localhost:5001

# %%
print(open('/Users/phongla/Data/test2/flask.log').read())

# %%
proc.terminate()
print("Stopped")
# Out:
# Stopped
